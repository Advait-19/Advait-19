# %%
import pandas as pd

# %%
# !pip install xlrd
# !pip install openpyxl
csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/TopSellingAlbums.csv'
df = pd.read_csv(csv_path)

# %%
df
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller      1982  0:42:19
# 1            AC/DC                    Back in Black      1980  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# ...

# %%
df.describe()
# Out:
#           Released  Music Recording Sales (millions)  \
# count     8.000000                          8.000000
# mean   1979.250000                         28.125000
# std       5.800246                          8.189322
# min    1973.000000                         20.600000
# 25%    1976.750000                         23.300000
# 50%    1977.000000                         26.750000
# 75%    1980.500000                         28.975000
# max    1992.000000                         46.000000
#
#        Claimed Sales (millions)     Rating
# count                  8.000000   8.000000
# mean                  46.125000   8.250000
# std                    8.271077   1.224745
# min                   40.000000   6.500000
# 25%                   41.500000   7.375000
# 50%                   43.500000   8.250000
# 75%                   46.250000   9.125000
# max                   65.000000  10.000000

# %%
df
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller      1982  0:42:19
# 1            AC/DC                    Back in Black      1980  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# ...

# %%
xlsx_path = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%204/Datasets/TopSellingAlbums.xlsx'

await download(xlsx_path, "TopSellingAlbums.xlsx")
df = pd.read_excel("TopSellingAlbums.xlsx")
df.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980   0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973   0:42:49
# 3  Whitney Houston              The Bodyguard      1992   0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977   0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# ...

# %% [markdown]
# READING DATA FROM POKEMON DATASET(CSV FILE)

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\KIIT0001\OneDrive\Desktop\Coding\Pythonscripts\Datasets\pokemon_data.csv')
#print(df.head(3))

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#print(df[['Name','Type 1','HP']][0:5])
print(df.iloc[4:10])
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %%
#print(df.iloc[7,1])
#for index,row in df.iterrows():
    #print(index,row['Name'])
df.loc[(df['Type 1']=='Dragon') & (df['Generation'].between(1,3))]
#set(df['Type 1'])
# Out:
#        #                     Name  Type 1   Type 2  TotalHP  Total   HP  \
# 159  147                  Dratini  Dragon      NaN      300    300   41
# 160  148                Dragonair  Dragon      NaN      420    420   61
# 161  149                Dragonite  Dragon   Flying      600    600   91
# 365  334                  Altaria  Dragon   Flying      490    490   75
# 366  334      AltariaMega Altaria  Dragon    Fairy      590    590   75
# 406  371                    Bagon  Dragon      NaN      300    300   45
# 407  372                  Shelgon  Dragon      NaN      420    420   65
# 408  373                Salamence  Dragon   Flying      600    600   95
# 409  373  SalamenceMega Salamence  Dragon   Flying      700    700   95
# 417  380                   Latias  Dragon  Psychic      600    600   80
# 418  380        LatiasMega Latias  Dragon  Psychic      700    700   80
# 419  381                   Latios  Dragon  Psychic      600    600   80
# ...

# %%
df.sort_values(['Type 1','HP'],ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['TotalHP']= df.loc[:,'HP':'Speed'].sum(axis=1)
df.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary  TotalHP
# 0       65     45           1      False      318
# 1       80     60           1      False      405
# 2      100     80           1      False      525
# 3      120     80           1      False      625

# %%
cols=list(df.columns.values)
df= df[cols[0:4]+ [cols[-1]] +cols[4:12]]
df= df.loc[:, df.columns[df.columns.get_loc('#'):df.columns.get_loc('Speed') + 1].tolist() + ['Legendary','Generation']]

# %%
df.columns.values[10]='Agility'

# %%
df.head(4)
# Out:
#    #           Name Type 1  Type 2  TotalHP  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison      318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison      405  60      62       63       80
# 2  3       Venusaur  Grass  Poison      525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison      625  80     100      123      122
#
#    Sp. Def  Speed  Legendary  Generation
# 0       65     45      False           1
# 1       80     60      False           1
# 2      100     80      False           1
# 3      120     80      False           1

# %%
df.to_csv(r'C:\Users\KIIT0001\OneDrive\Desktop\Coding\Pythonscripts\Datasets\pokedata_mod.csv',index=False)

# %%
df.to_excel(r'C:\Users\KIIT0001\OneDrive\Desktop\Coding\Pythonscripts\Datasets\pokedata_mod.xlsx', index=False)

# %%
new_df=df.loc[(df['Type 1']=='Water') & (df['Type 2']=='Dark') & (df['HP']>50)]

# %%
new_df
# Out:
#      #                   Name Type 1 Type 2  TotalHP  HP  Attack  Defense  \
# 0  130  GyaradosMega Gyarados  Water   Dark      640  95     155      109
# 1  319               Sharpedo  Water   Dark      460  70     120       40
# 2  319  SharpedoMega Sharpedo  Water   Dark      560  70     140       70
# 3  342              Crawdaunt  Water   Dark      468  63     120       85
# 4  658               Greninja  Water   Dark      530  72      95       67
#
#    Sp. Atk  Sp. Def  Agility  Legendary  Generation
# 0       70      130       81      False           1
# 1       95       40       95      False           3
# 2      110       65      105      False           3
# 3       90       55       55      False           3
# 4      103       71      122      False           6

# %%
new_df.reset_index(drop=True,inplace=True)

# %%
new_df.to_csv(r'C:\Users\KIIT0001\OneDrive\Desktop\Coding\Pythonscripts\Datasets\filtered.csv')

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #              Name    Type 1    Type 2  TotalHP   HP  Attack  Defense  \
# 3      3     Mega Venusaur     Grass    Poison      625   80     100      123
# 7      6  Mega Charizard X      Fire    Dragon      634   78     130      111
# 8      6  Mega Charizard Y      Fire    Flying      634   78     104       78
# 12     9    Mega Blastoise     Water       NaN      630   79     103      120
# 19    15     Mega Beedrill       Bug    Poison      495   65     150       40
# 23    18      Mega Pidgeot    Normal    Flying      579   83      80       80
# 71    65     Mega Alakazam   Psychic       NaN      590   55      50       65
# 87    80      Mega Slowbro     Water   Psychic      590   95      75      180
# 102   94       Mega Gengar     Ghost    Poison      600   60      65       80
# 124  115   Mega Kangaskhan    Normal       NaN      590  105     125      100
# 137  127       Mega Pinsir       Bug    Flying      600   65     155      120
# ...

# %%
import re

# %%
# Assume `df` is your larger DataFrame
df["Name"] = df["Name"].str.replace(r"(\w+)Mega \1", r"Mega \1", regex=True)

# %%
df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]
# Out:
#        #           Name Type 1  Type 2  TotalHP   HP  Attack  Defense  \
# 0      1      Bulbasaur  Grass  Poison      318   45      49       49
# 1      2        Ivysaur  Grass  Poison      405   60      62       63
# 2      3       Venusaur  Grass  Poison      525   80      82       83
# 3      3  Mega Venusaur  Grass  Poison      625   80     100      123
# 4      4     Charmander   Fire     NaN      309   39      52       43
# ..   ...            ...    ...     ...      ...  ...     ...      ...
# 735  667         Litleo   Fire  Normal      369   62      50       58
# 736  668         Pyroar   Fire  Normal      507   86      68       72
# 740  672         Skiddo  Grass     NaN      350   66      65       48
# 741  673         Gogoat  Grass     NaN      531  123     100       62
# 799  721      Volcanion   Fire   Water      600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary  Generation
# 0         65       65     45      False           1
# ...

# %%
orig=pd.read_csv(r'C:\Users\KIIT0001\OneDrive\Desktop\Coding\Pythonscripts\Datasets\pokemon_data.csv')

# %%
df.to_csv(r'C:\Users\KIIT0001\OneDrive\Desktop\Coding\Pythonscripts\Datasets\pokemon_data.csv', index=False)

# %%
df.loc[df['Name'].str.contains(r'^pi\D*', flags=re.I, regex=True)]
# Out:
#        #       Name    Type 1    Type 2  TotalHP   HP  Attack  Defense  \
# 20    16     Pidgey    Normal    Flying      251   40      45       40
# 21    17  Pidgeotto    Normal    Flying      349   63      60       55
# 22    18    Pidgeot    Normal    Flying      479   83      80       75
# 30    25    Pikachu  Electric       NaN      320   35      55       40
# 136  127     Pinsir       Bug       NaN      500   65     125      100
# 186  172      Pichu  Electric       NaN      205   20      40       15
# 219  204     Pineco       Bug       NaN      290   50      65       90
# 239  221  Piloswine       Ice    Ground      450  100     100       80
# 438  393     Piplup     Water       NaN      314   53      51       53
# 558  499    Pignite      Fire  Fighting      418   90      93       55
# 578  519     Pidove    Normal    Flying      264   50      55       50
#
#      Sp. Atk  Sp. Def  Speed  Legendary  Generation
# 20        35       35     56      False           1
# ...

# %%
df.loc[df['Type 1']=='Flame']
# Out:
#        #                     Name Type 1    Type 2  TotalHP   HP  Attack  \
# 4      4               Charmander  Flame       NaN      309   39      52
# 5      5               Charmeleon  Flame       NaN      405   58      64
# 6      6                Charizard  Flame    Flying      534   78      84
# 7      6         Mega Charizard X  Flame    Dragon      634   78     130
# 8      6         Mega Charizard Y  Flame    Flying      634   78     104
# 42    37                   Vulpix  Flame       NaN      299   38      41
# 43    38                Ninetales  Flame       NaN      505   73      76
# 63    58                Growlithe  Flame       NaN      350   55      70
# 64    59                 Arcanine  Flame       NaN      555   90     110
# 83    77                   Ponyta  Flame       NaN      410   50      85
# 84    78                 Rapidash  Flame       NaN      500   65     100
# 135  126                   Magmar  Flame       NaN      495   65      95
# ...

# %%
df.loc[df['Type 1']=='Fire','Type 1'] = 'Flame'

# %%
df.to_excel(r'C:\Users\KIIT0001\OneDrive\Desktop\Coding\Pythonscripts\Datasets\pokemon_mod.xlsx', index=False)

# %%
df.head()
# Out:
#    #           Name Type 1  Type 2  TotalHP  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison      318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison      405  60      62       63       80
# 2  3       Venusaur  Grass  Poison      525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison      625  80     100      123      122
# 4  4     Charmander  Flame     NaN      309  39      52       43       60
#
#    Sp. Def  Speed  Legendary  Generation
# 0       65     45      False           1
# 1       80     60      False           1
# 2      100     80      False           1
# 3      120     80      False           1
# 4       50     65      False           1

# %%
df.to_csv(r'C:\Users\KIIT0001\OneDrive\Desktop\Coding\Pythonscripts\Datasets\pokemon_mod.csv', index=False)

# %%
df.groupby(['Type 1']).mean(numeric_only=True).sort_values('TotalHP',ascending=False)
#df.head()
# Out:
#                    #     TotalHP         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Flame     327.403846  458.076923  69.903846   84.769231   67.769231
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# ...

# %%
df['Count']=1
df
#df.groupby(['Type 1']).count()
# Out:
#        #                 Name   Type 1  Type 2  TotalHP  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison      318  45      49       49
# 1      2              Ivysaur    Grass  Poison      405  60      62       63
# 2      3             Venusaur    Grass  Poison      525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison      625  80     100      123
# 4      4           Charmander    Flame     NaN      309  39      52       43
# ..   ...                  ...      ...     ...      ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy      600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy      700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost      600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark      680  80     160       60
# 799  721            Volcanion    Flame   Water      600  80     110      120
#
# ...

# %%
df.groupby(['Type 1','Type 2']).count()['Count']
# Out:
#             #  Name  Type 2  TotalHP   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52       69   69      69       69       69       69
# Dark       31    31      21       31   31      31       31       31       31
# Dragon     32    32      21       32   32      32       32       32       32
# Electric   44    44      17       44   44      44       44       44       44
# Fairy      17    17       2       17   17      17       17       17       17
# Fighting   27    27       7       27   27      27       27       27       27
# Flame      52    52      24       52   52      52       52       52       52
# Flying      4     4       2        4    4       4        4        4        4
# Ghost      32    32      22       32   32      32       32       32       32
# Grass      70    70      37       70   70      70       70       70       70
# Ground     32    32      19       32   32      32       32       32       32
# ...

# %%
new_df=pd.DataFrame(columns=df.columns)

for data in pd.read_csv(r'C:\Users\KIIT0001\OneDrive\Desktop\Coding\Pythonscripts\Datasets\pokemon_mod.csv', chunksize=25):
    results= data.groupby(['Type 1']).count()
    new_df=pd.concat([new_df,results])

new_df
# Out:
#           # Name Type 1 Type 2 TotalHP  HP Attack Defense Sp. Atk Sp. Def  \
# Bug       7    7    NaN      5       7   7      7       7       7       7
# Flame     5    5    NaN      3       5   5      5       5       5       5
# Grass     4    4    NaN      4       4   4      4       4       4       4
# Normal    5    5    NaN      4       5   5      5       5       5       5
# Water     4    4    NaN      0       4   4      4       4       4       4
# ...      ..  ...    ...    ...     ...  ..    ...     ...     ...     ...
# Ghost    10   10    NaN     10      10  10     10      10      10      10
# Ice       2    2    NaN      0       2   2      2       2       2       2
# Psychic   2    2    NaN      2       2   2      2       2       2       2
# Rock      2    2    NaN      2       2   2      2       2       2       2
# Steel     1    1    NaN      1       1   1      1       1       1       1
#
#         Speed Legendary Generation  Count
# ...

# %%
import pandas as pd
df=pd.read_excel(r'C:\Users\KIIT0001\OneDrive\Desktop\Coding\Pythonscripts\Datasets\pokemon_mod.xlsx')
df
# Out:
#        #                 Name   Type 1  Type 2  TotalHP  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison      318  45      49       49
# 1      2              Ivysaur    Grass  Poison      405  60      62       63
# 2      3             Venusaur    Grass  Poison      525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison      625  80     100      123
# 4      4           Charmander    Flame     NaN      309  39      52       43
# ..   ...                  ...      ...     ...      ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy      600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy      700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost      600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark      680  80     160       60
# 799  721            Volcanion    Flame   Water      600  80     110      120
#
# ...

# %%
df.head()
# Out:
#    #           Name Type 1  Type 2  TotalHP  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison      318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison      405  60      62       63       80
# 2  3       Venusaur  Grass  Poison      525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison      625  80     100      123      122
# 4  4     Charmander  Flame     NaN      309  39      52       43       60
#
#    Sp. Def  Speed  Legendary  Generation
# 0       65     45      False           1
# 1       80     60      False           1
# 2      100     80      False           1
# 3      120     80      False           1
# 4       50     65      False           1
