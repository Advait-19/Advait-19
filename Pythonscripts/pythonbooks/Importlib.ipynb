# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Basic Math

# %%
#basic math
4*5
# Out:
# 20

# %%
np.exp(10)
# Out:
# np.float64(22026.465794806718)

# %%
sentence="first notebook"

# %%
sentence.upper()
# Out:
# 'FIRST NOTEBOOK'

# %%
sentence.capitalize()
# Out:
# 'First notebook'

# %%
import time

start=time.time()
for i in range(999999):
    if i%200000==0:
        print(i)
        print(time.time()-start)
# Out:
# 0
# 0.0
# 200000
# 0.019301176071166992
# 400000
# 0.044670820236206055
# 600000
# 0.07240104675292969
# 800000
# 0.08876562118530273

# %%
list=[1,2,3,4,5]
arr=np.array(list)
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr*2+2
# Out:
# array([ 4,  6,  8, 10, 12])

# %%
arr=[[[1,2],[3,4],[5,6]]]
arr=np.array(arr)
arr
# Out:
# array([[[1, 2],
#         [3, 4],
#         [5, 6]]])

# %%
print(arr[0,1,0])
# Out:
# 3

# %%
arr*2+3
# Out:
# array([[[ 5,  7],
#         [ 9, 11],
#         [13, 15]]])
